# %% [markdown]
# ## OPEN THE LOGFILE

# %%
#with this procedure i am opening a dialog box in order to grab the path of the file
from tkinter.filedialog import askopenfilename
import os

# %%
#this will be the FULL PATH of the zip file
filename = askopenfilename(filetypes =[("todos", "*.*")])

# %%
filename
# Out:
# 'C:/Users/andres/Documents/Python_Projects/schwind_logfile_reader/Log_M341_2020-06-17.zip'

# %%
#this is the file name WITHOUT the path
base=os.path.basename(filename)

# %%
base
# Out:
# 'Log_M341_2020-06-17.zip'

# %% [markdown]
# ## Extract all files from logfile zip file

# %%
#Import libraries to unzip the logfile
from zipfile import ZipFile

# %%
#the zip file will be in ZIP variable
zip=ZipFile(base)

# %%
#UNZIP the file
zip.extractall()

# %%
zip.close()

# %% [markdown]
# ## Read all the files unziped

# %%
import os

# %%
files = os.listdir()

# %%
#list of all files in the directory
files
# Out:
# ['.ipynb_checkpoints',
#  '2020-06-17__12-15-39.log',
#  'CAMerrorLog.dat',
#  'confs',
#  'CrdStatus',
#  'Hdspace',
#  'laser.cfg',
#  'laser.slb',
#  'logfile_notebook.ipynb',
#  'logfile_separadores.py',
#  'Log_M341_2020-06-17.zip',
#  'Mcu_boottime',
#  'Mcu_logs',
#  'Nozzle',
#  'README.md',
#  'schwind_logfile_reader.py',
#  'ServiceActivity.log',
#  'SpotAtLastDriftTest.bmp',
#  'ssw.slb',
#  'SysConfigInfo',
#  'system.sys',
#  'Users']

# %% [markdown]
# ## Grabing the file name from the original logfile
# in this procedure we need to find the file.LOG with the right date.
# the right day is always in the ORIGINAL name of the ZIP file taken from the Amaris System.
# so, we are taking the number and we will find the file in the unziped list

# %%
#This is the filename without te extension
logfile_name=os.path.splitext(base)

# %%
logfilename=logfile_name[0]

# %%
logfilename
# Out:
# 'Log_M341_2020-06-17'

# %%
# Import Regular expressions to find the pathern of the DATE
import re

# %%
#re.search("([0-9]{2}\-[0-9]{2}\-[0-9]{4})", fileName)
date_number = re.search("([0-9]{4}\-[0-9]{2}\-[0-9]{2})", logfilename)

# %%
date_number[0]
# Out:
# '2020-06-17'

# %%
# In this code i am looking in the list of unziped files and finding the right file
# with the LOG extension
file_to_open = next((s for s in files if date_number[0] in s),None)

# %%
file_to_open
# Out:
# '2020-06-17__12-15-39.log'

# %% [markdown]
# ## Opening the file to analyse in PANDAS

# %%
import pandas as pd

# %%
import csv

# %%
logfile_csv = pd.read_csv(file_to_open, delimiter="|", header=None, names =[1,2,3,4,5,6], encoding="ISO-8859-1")

# %%
df = pd.DataFrame(logfile_csv)

# %%
df
# Out:
#                                1         2         3               4  \
# 0                          begin       NaN       NaN             NaN
# 1      2019-12-03__06-06-53.625                        APP
# 2      2019-12-03__06-07-34.453   2102-021             APP
# 3      2019-12-03__06-07-34.453                        APP
# 4      2019-12-03__06-07-37.875                        APP
# 5      2019-12-03__06-07-38.281                        APP
# 6      2019-12-03__06-07-45.375                        APP
# 11494  2020-06-17__12-15-30.703                        APP
# 11495                       ½u       NaN       NaN             NaN
#
#                                                        5    6
# 0                                                    NaN  NaN
# 1       START=APP-SESSION============================...  NaN
# 2       LOGIN Application Software   Version:6.1.2117...  NaN
# 3         LaserHz TrtLF,TrtHF,FtLF,FtHF: 500,500,500,500  NaN
# 4       MCU is now online but still inside starting u...  NaN
# 5                      Startup: (70) Checking components  NaN
# 6                Startup: (6) Waiting for scanner warmup  NaN
# 7                      Startup: (25) Checking components  NaN
# 8                   Startup: (4) Laser warmup is running  NaN
# 9       Startup: (5) Laser energy measurement is running  NaN
# 10                     Startup: (17) Checking attenuator  NaN
# 11                 Startup: (22) Laser warmup is running  NaN
# 12                                 Startup: (10) Debries  NaN
# 13                    Startup: (15) Evacuating beam path  NaN
# 14                     Startup: (21) Checking components  NaN
# 15                 Amaris MCU program is starting ......  NaN
# 16                                     MainState STARTUP  NaN
# 17      Esiris start up: Waiting till Scanner warm up...  NaN
# 18                           Internal system information  NaN
# 19      FluenceTest: EndTime2 reached. FT is invalid ...  NaN
# 20      FluenceTest: EndTime2 reached. FT is invalid ...  NaN
# 21         Init treatment: Last fluencetest is not valid  NaN
# 22                        A Modul is not yet initialize.  NaN
# 23                                  Startup is finished.  NaN
# 24                MCU starting up process has finished..  NaN
# 25      High Energy: 420  Low Energy: 360  HighFluenc...  NaN
# 26                                      MCU type:Lippert  NaN
# 27      Temperature  MCU CPU:33  Mainboard:0  Chipset...  NaN
# 28      OK: Check LaserSource Integrity. EXSO-500_500...  NaN
# 29      AttenuatorSwitchTime LowToHigh: 23 HighToLow: 27  NaN
# ...                                                  ...  ...
# 11466                       System Serial (branded):M341  NaN
# 11467                      Disk free space: C:18%, D:50%  NaN
# 11468    FluenceTest validness (menu display): REQUIRED!  NaN
# 11469                                   Menu "Functions"  NaN
# 11470                                 Menu "Fluencetest"  NaN
# 11471                                  MainState SERVICE  NaN
# 11472                              MainState MAINTENANCE  NaN
# 11473   START#FLUENCETEST############################...  NaN
# 11474                           Rotating holes angle:270  NaN
# 11475            Pulsecounter before FT and DT:226430863  NaN
# 11476                                  MainState SERVICE  NaN
# 11477                              MainState MAINTENANCE  NaN
# 11478                        LACU_HI: 3506 LACU_LO: 2357  NaN
# 11479   Fluence values: High Fluence: 634   Low Fluen...  NaN
# 11480   Fluence Values:__High Fluence: 634 nm  [Min: ...  NaN
# 11481                            DriftTest: Circle begin  NaN
# 11482                                     PaperCheck: OK  NaN
# 11483                                Circle ablating ...  NaN
# 11484   DriftTest: Please press foot switch to start ...  NaN
# 11485   END#FLUENCETEST_OK###########################...  NaN
# 11486                                  MainState SERVICE  NaN
# 11487                       Drift Test Result: X: 3 Y: 4  NaN
# 11488                                   Drift_prev:-3;-6  NaN
# 11489   vectorlength(PrevDTPositionResult-CurrDTPosit...  NaN
# 11490                              Drift test successful  NaN
# 11491             Pulsecounter after FT and DT:226489495  NaN
# 11492                                  MainState SERVICE  NaN
# 11493               ################FluencetestMENU EXIT  NaN
# 11494                             Menu "Export Logfiles"  NaN
# 11495                                                NaN  NaN
#
# [11496 rows x 6 columns]

# %%
# split date and hour in two new columns 

# new data frame with split value columns 
#new = data["Name"].str.split(" ", n = 1, expand = True) 
  
# making separate first name column from new data frame 
# 11473  12-09-50.406
# 11474  12-09-50.406
# 11475  12-09-51.875
# 11476  12-09-51.263
# 11477  12-09-52.983
# 11478  12-12-30.015
# 11479  12-12-33.843
# 11480  12-12-33.843
# 11481  12-14-52.281
# 11482  12-14-52.375
# 11483  12-14-52.375
# 11484  12-14-52.039
# 11485  12-15-00.828
# 11486  12-15-02.123
# 11487  12-15-10.859
# 11488  12-15-12.187
# 11489  12-15-16.031
# 11490  12-15-16.234
# 11491  12-15-16.250
# 11492  12-15-14.122
# 11493  12-15-22.921
# 11494  12-15-30.703
# 11495          None
#
# [11496 rows x 8 columns]

# %% [markdown]
# ## LAST FLUENCE

# %%
#code for fluence is 2116-042, so I looked the rows with this value on column 2
#df.loc[df['column_name'] == some_value]
#date_number is the date of the current logfile

last_fluence = df.loc[(df[2]=="2116-042")&(df["date"]>=date_number[0])]

# %%
last_fluence
# Out:
#                                1         2         3               4  \
# 10328  2020-06-17__10-13-48.812   2116-042             APP
# 11317  2020-06-17__11-33-27.390   2116-042             APP
# 11414  2020-06-17__12-06-36.125   2116-042             APP
# 11479  2020-06-17__12-12-33.843   2116-042             APP
#
#                                                        5    6        date  \
# 10328   Fluence values: High Fluence: 590   Low Fluen...  NaN  2020-06-17
# 11317   Fluence values: High Fluence: 564   Low Fluen...  NaN  2020-06-17
# 11414   Fluence values: High Fluence: 591   Low Fluen...  NaN  2020-06-17
# 11479   Fluence values: High Fluence: 634   Low Fluen...  NaN  2020-06-17
#
#                hour
# 10328  10-13-48.812
# 11317  11-33-27.390
# 11414  12-06-36.125
# 11479  12-12-33.843

# %%
#the column 5 is where all the fluence values are.
last_fluence[5]
# Out:
# 10328     Fluence values: High Fluence: 590   Low Fluen...
# 11317     Fluence values: High Fluence: 564   Low Fluen...
# 11414     Fluence values: High Fluence: 591   Low Fluen...
# 11479     Fluence values: High Fluence: 634   Low Fluen...
# Name: 5, dtype: object

# %%
#In this step, I split the column 5 in order to have every value in its own column
values_last_fluence = last_fluence[5].str.split("   ", n = 0, expand = True)

# %%
#removing "Fluence values: " string from the column 0 - in order to clean the data
#removing strings before the values on each column
values_last_fluence[0] = values_last_fluence[0].str.replace("Fluence values: High Fluence: ","")
values_last_fluence[1] = values_last_fluence[1].str.replace("Low Fluence: ","")
values_last_fluence[2] = values_last_fluence[2].str.replace("HV: ", "")
values_last_fluence[3] = values_last_fluence[3].str.replace("NominalHF: ", "")
values_last_fluence[4] = values_last_fluence[4].str.replace("NominalLF: ", "")
values_last_fluence[5] = values_last_fluence[5].str.replace("E_preset_HI : ", "")
values_last_fluence[6] = values_last_fluence[6].str.replace("E_preset_LO : ", "")
values_last_fluence[7] = values_last_fluence[7].str.replace("HV_min:  ", "")
values_last_fluence[8] = values_last_fluence[8].str.replace("HV_max:  ", "")
values_last_fluence[9] = values_last_fluence[9].str.replace("LaserTemperature: ", "")

# %%
#rename the column name
values_last_fluence.columns=["High Fluence", "Low Fluence", "HV", "Nominal HF", "Nominal LF", "High Energy", "Low Energy", "HV min", "HV max", "Temp"]

# %%
#last fluence value
values_last_fluence.tail(1)
# Out:
#       High Fluence Low Fluence   HV Nominal HF Nominal LF High Energy  \
# 11479          634         517  928        677        562         480
#
#       Low Energy HV min HV max Temp
# 11479        420    891    967   24

# %% [markdown]
# ## LAST PULSES AND TEMPERATURE

# %%
#I search for the string "  Temp.  ", where the value of the pulse is. 
#and with the "date" iqual or grater that the current date.

pulses_temp = df.loc[(df[2]=="  Temp. ")&(df["date"]>=date_number[0])]

# %%
#In this step, I split the column 5 in order to have every value in its own column
values_pulses_temp = pulses_temp[5].str.split("  ", n = 0, expand = True)

# %%
#removing values in order to clean the data
#rename each column to identify values

values_pulses_temp[1] = values_pulses_temp[1].str.replace("MCU CPU:","")
values_pulses_temp[2] = values_pulses_temp[2].str.replace("Mainboard:","")
values_pulses_temp[3] = values_pulses_temp[3].str.replace("Chipset:","")
values_pulses_temp[4] = values_pulses_temp[4].str.replace("LACU:","")
values_pulses_temp[5] = values_pulses_temp[5].str.replace("Humidity\%:","")
values_pulses_temp[6] = values_pulses_temp[6].str.replace("Pulsecounter:","")


values_pulses_temp.columns=["", "mcu_temp", "mainboard_temp", "chipset_temp", "lacu_temp", "humidity", "pulsecounter"]

# %%
#las values of temp humidity and pulsecounter
values_pulses_temp.tail(1)
# Out:
#                     mcu_temp mainboard_temp chipset_temp lacu_temp humidity  \
# 11454   Temperature       41              0           49        24       52
#
#       pulsecounter
# 11454    226430863

# %% [markdown]
# ## LASER SERIAL NUMBER

# %%
#Searching the string "2102-021" wich is the code where the laser serial number and software version is located
serial_version = df.loc[(df[2]=="2102-021")&(df["date"]>=date_number[0])]

# %%
#In this step, I split the column 5 in order to have every value in its own column
values_serial_version = serial_version[5].str.split("   ", n = 0, expand = True)

# %%
values_serial_version
# Out:
#                                  0                     1          2  \
# 10140   LOGIN Application Software  Version:6.1.2117.700  User:DEMO
# 10266   LOGIN Application Software  Version:6.1.2117.700  User:SETS
# 11263   LOGIN Application Software  Version:6.1.2117.700  User:SETS
# 11340   LOGIN Application Software  Version:6.1.2117.700  User:SETS
# 11373   LOGIN Application Software  Version:6.1.2117.700  User:SETS
# 11442   LOGIN Application Software  Version:6.1.2117.700  User:SETS
#
#                               3
# 10140  System Serial (ini):M341
# 10266  System Serial (ini):M341
# 11263  System Serial (ini):M341
# 11340  System Serial (ini):M341
# 11373  System Serial (ini):M341
# 11442  System Serial (ini):M341

# %%
#removing values in order to clean the data
#rename each column to identify values
values_serial_version[1] = values_serial_version[1].str.replace("Version:","")
values_serial_version[3] = values_serial_version[3].str.replace("System Serial \(ini\):","")
values_serial_version.columns=["", "version", "", "serial"]

# %%
values_serial_version.tail(1)
# Out:
#                                          version            serial
# 11442   LOGIN Application Software  6.1.2117.700  User:SETS   M341

# %% [markdown]
# ## Gas Exchage

# %%
#searching for the string "2115-012" where gas exchange is located
gas = df.loc[(df[2]=="2115-012")&(df["date"]>=date_number[0])]

# %%
gas
# Out:
#                                1         2         3               4  \
# 10309  2020-06-17__10-01-06.843   2115-012             APP
#
#                                                        5    6        date  \
# 10309   START#GasExchange############################...  NaN  2020-06-17
#
#                hour
# 10309  10-01-06.843

# %%
gas2 = df.loc[(df[2]=="2115-012")]

# %%
gas2
# Out:
#                                1         2         3               4  \
# 1424   2019-12-12__06-58-06.890   2115-012             APP
# 3158   2020-01-28__06-31-23.890   2115-012             APP
# 4160   2020-02-20__13-36-27.890   2115-012             APP
# 5796   2020-03-17__10-10-02.375   2115-012             APP
# 6931   2020-03-19__12-18-32.984   2115-012             APP
# 7184   2020-04-15__11-16-03.687   2115-012             APP
# 8009   2020-06-09__12-01-50.015   2115-012             APP
# 10309  2020-06-17__10-01-06.843   2115-012             APP
#
#                                                        5    6        date  \
# 1424    START#GasExchange############################...  NaN  2019-12-12
# 3158    START#GasExchange############################...  NaN  2020-01-28
# 4160    START#GasExchange############################...  NaN  2020-02-20
# 5796    START#GasExchange############################...  NaN  2020-03-17
# 6931    START#GasExchange############################...  NaN  2020-03-19
# 7184    START#GasExchange############################...  NaN  2020-04-15
# 8009    START#GasExchange############################...  NaN  2020-06-09
# 10309   START#GasExchange############################...  NaN  2020-06-17
#
#                hour
# 1424   06-58-06.890
# 3158   06-31-23.890
# 4160   13-36-27.890
# 5796   10-10-02.375
# 6931   12-18-32.984
# 7184   11-16-03.687
# 8009   12-01-50.015
# 10309  10-01-06.843

# %%
#debo buscar como obtener el indece donde se encuentra el valor del gas exchange de el dataframe completo
#como extraer el indice del data frame completo donde se encuentra el valor del cambio de gas
df.iloc[1426]
# Out:
# 1                               2019-12-12__06-58-19.312
# 2
# 3
# 4                                           APP
# 5        GAS Status (before exchange): Remaining possi...
# 6                                                     NaN
# date                                           2019-12-12
# hour                                         06-58-19.312
# Name: 1426, dtype: object

# %%
date_number[0]
# Out:
# '2020-05-20'

# %%
df.loc[df["hour"]=="04-54-28.671"]
# Out:
#                               1         2         3               4  \
# 5242  2020-05-20__04-54-28.671                        APP
#
#                             5    6        date          hour
# 5242   Pulsecounter:292496361  NaN  2020-05-20  04-54-28.671

# %%
fluencia
# Out:
# Empty DataFrame
# Columns: [1, 2, 3, 4, 5, 6, date, hour]
# Index: []

# %%
#row with fluence and last date
fluence_date = df.loc[(df[2]=="2116-042")&(df["hour"]=="03-45-20.312")]
#fluence_h = df.loc[df["hour"]=="03-45-20.312"]

# %%
fluence_date
# Out:
#                               1         2         3               4  \
# 4531  2020-05-20__03-45-20.312   2116-042             APP
#
#                                                       5    6        date  \
# 4531   Fluence values: High Fluence: 655   Low Fluen...  NaN  2020-05-20
#
#               hour
# 4531  03-45-20.312
